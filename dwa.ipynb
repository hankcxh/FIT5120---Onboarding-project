# %%
import pandas as pd

vehicle_data_path = "/Users/aniketnamjoshi/Documents/GitHub/FIT5120---Onboarding-project/Datasets/vehicle_data.xls"

df = pd.read_excel(vehicle_data_path, sheet_name="Table_1", header=4)

# %%
df
# Out:
#                           Unnamed: 0 New South Wales Victoria Queensland  \
# 0                                NaN             no.      no.        no.
# 1                 PASSENGER VEHICLES             NaN      NaN        NaN
# 2                               2016         4134786  3666505    2715055
# 3                               2020         4348429  3963818    2919855
# 4                               2021         4404673  3970844    2975229
# 5                         CAMPERVANS             NaN      NaN        NaN
# 6                               2016           15345    13118      14864
# 7                               2020           19601    15268      18131
# 8                               2021           20699    15155      18608
# 9          LIGHT COMMERCIAL VEHICLES             NaN      NaN        NaN
# 10                              2016          804665   652020     775864
# 11                              2020          941140   753341     887239
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'New South Wales', 'Victoria', 'Queensland',
#        'South Australia', 'Western Australia', 'Tasmania',
#        'Northern Territory', 'Australian Capital Territory', 'Australia'],
#       dtype='object')

# %%
df = df.rename(columns={df.columns[0]: 'vehicle_type'})

# %%
df
# Out:
#                         vehicle_type New South Wales Victoria Queensland  \
# 0                                NaN             no.      no.        no.
# 1                 PASSENGER VEHICLES             NaN      NaN        NaN
# 2                               2016         4134786  3666505    2715055
# 3                               2020         4348429  3963818    2919855
# 4                               2021         4404673  3970844    2975229
# 5                         CAMPERVANS             NaN      NaN        NaN
# 6                               2016           15345    13118      14864
# 7                               2020           19601    15268      18131
# 8                               2021           20699    15155      18608
# 9          LIGHT COMMERCIAL VEHICLES             NaN      NaN        NaN
# 10                              2016          804665   652020     775864
# 11                              2020          941140   753341     887239
# ...

# %%
df['vehicle_type'] = df['vehicle_type'].ffill()
